# %%
import sklearn

import matplotlib.pyplot as plt

import numpy as np

import pandas as pd

# %matplotlib inline

import seaborn as sns

# %%
#Partie 1

house_data = pd.read_csv("D:\Ecole\BigData\Data\house_pricing.csv")

# %%
house_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
plt.scatter(house_data.LotArea,house_data.SalePrice)

# %%
house_data_affined = house_data[(house_data.LotArea < 20000) & (house_data.SalePrice < 500000)]

plt.scatter(house_data_affined.LotArea,house_data_affined.SalePrice)

# %%
plt.scatter(house_data.LotFrontage,house_data.LotArea)

# %%
house_data_affined = house_data[(house_data.LotFrontage < 200) & (house_data.LotArea < 100000)]

plt.scatter(house_data_affined.LotFrontage,house_data_affined.LotArea)

# %%
#Partie 2

sales_data = pd.read_csv("D:\Ecole\BigData\Data\sales_predictions.csv")

# %%
sales_data
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
sns.relplot(x='date',y='item_id',data=sales_data)

# %%
sales_data_sample = sales_data.sample(50)

# %%
sales_data_sample
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2175805  13.11.2014              22       25     4870       999.0
# 411781   06.04.2013               3       56    15447       999.0
# 2800699  29.08.2015              31       59     4349      1399.0
# 1462201  30.03.2014              14       53    14227        99.0
# 2871853  24.09.2015              32       34     4385       599.0
# 281264   02.03.2013               2       19     1830       299.5
# 2376269  14.01.2015              24       35     3342      2999.0
# 1836875  06.07.2014              18       15    16206       699.0
# 1437209  01.02.2014              13       47     6247       399.0
# 1529580  24.03.2014              14       45     5672      2890.0
# 2180010  03.11.2014              22       45    10942       199.0
# 2315042  07.12.2014              23       22    17662      1999.0
# 61292    08.01.2013               0       31     2321       999.0
# ...

# %%
sns.relplot(x='date',y='item_id',data=sales_data_sample, sizes=(20, 6))

#On voit que les points ont été démultipliés et le graphique est beaucoup plus lisible

# %%
for i, r in sales_data_sample.iterrows():
    r['date'] = pd.to_datetime(r['date'])
    
sns.relplot(x='date',y='item_id',data=sales_data_sample, sizes=(20, 6))

# %%
#Partie 3

ibm_data = pd.read_csv("D:\Ecole\BigData\Data\ibm_hr_attrition.csv")

# %%
ibm_data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
graphCatplot = sns.catplot(x='Department', y='JobSatisfaction', data=ibm_data)

# %%
graphBoxplot = sns.barplot(x='Department', y='JobSatisfaction', data=ibm_data)

# %%
ibm_data.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
for i, r in ibm_data.iterrows():
    if r['Attrition'] == 0:
       r['Attrition'] = 'No'
    elif r['Attrition'] == 1:
         r['Attrition'] = 'Yes'

# %%
plt.bar(ibm_data.EducationField,ibm_data.Attrition)
# Out:
# <BarContainer object of 1470 artists>

# %%
# Partie 4

graphDistPlot = sns.distplot(ibm_data.MonthlyIncome)

# %%
graphDistPlot = sns.distplot(ibm_data.MonthlyIncome  <= 5000)

# %%
# Partie 5

plt.figure(figsize=(20,6))
ibm_data['Attrition'] = ibm_data['Attrition'].replace('Yes',1).replace('No',0)
line1 = sns.lmplot(x="DistanceFromHome", y="Attrition", data=ibm_data)

# %%
line2 = sns.lmplot(x="YearsWithCurrManager", y="Attrition", data=ibm_data)

# %%
# Partie 5

heatmap_data = pd.read_csv("D:\Ecole\BigData\Data\house_pricing.csv")

# %%
lastHouses = heatmap_data.tail(15)

# %%
lastHouses.corr()
# Out:
#                          Id  MSSubClass  LotFrontage   LotArea   OverallQual  \
# Id             1.000000e+00   -0.299933     0.170671 -0.176641  1.175185e-17
# MSSubClass    -2.999333e-01    1.000000    -0.879089 -0.643601 -2.135655e-01
# LotFrontage    1.706710e-01   -0.879089     1.000000  0.914186  2.928409e-01
# LotArea       -1.766413e-01   -0.643601     0.914186  1.000000 -1.544585e-01
# OverallQual    1.175185e-17   -0.213565     0.292841 -0.154458  1.000000e+00
# OverallCond    1.479836e-01    0.051806    -0.176484  0.150015 -1.694586e-01
# YearBuilt      3.847864e-02    0.052251     0.019051 -0.148001  4.729485e-01
# YearRemodAdd   3.193971e-01   -0.124680     0.211581 -0.204825  3.828724e-01
# MasVnrArea    -3.907955e-01   -0.121045     0.279790  0.251578  5.706548e-01
# BsmtFinSF1    -2.039226e-02    0.098483    -0.049288  0.026653  2.180785e-01
# BsmtFinSF2     2.372469e-01   -0.198927     0.142105 -0.058416 -1.765379e-01
# ...

# %%
sns.heatmap(lastHouses.corr())
plt.show()

# %%
sns.heatmap(lastHouses.corr(), annot=True)
plt.show()
